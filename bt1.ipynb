 
The crocodile knew he had been tricked, and felt ashamed for his actions. He went away.
"""

# %%
out_story1 = """
एक समय की बात है। एक घना जंगल था जिसमें एक आम का पेड़ नदी के किनारे खड़ा था। उस पेड़ पर एक चालाक और खुशमिजाज बंदर रहता था। वह हर दिन मीठे-मीठे आम खाकर खुश रहता। एक दिन एक भूखा घड़ियाल नदी से निकलकर उस पेड़ के नीचे आया। बंदर ने उसे आम खिलाए दोनों में दोस्ती हो गई। अब बंदर रोज घड़ियाल को आम देने लगा। एक दिन घड़ियाल ने अपनी पत्नी को आम खिलाए। पत्नी को आम तो पसंद आए लेकिन वह लालची हो गई। उसने घड़ियाल से कहा, अगर आम इतने स्वादिष्ट हैं तो सोचो बंदर का दिल कितना मीठा होगा। ने ने जिद की कि वह बंदर का दिल खाना चाहती है। घड़ियाल पहले तो झिझका पर पत्नी के दबाव में आ गया। अगले दिन वह बंदर को पेड़ से नीचे बुलाकर कहता है, मुझे मेरी पत्नी से मिलवाने चलो वह तुमसे मिलना चाहती है। बंदर भोलेपन में उसकी पीठ पर बैठ गया। नदी के बीच में घड़ियाल ने सच्चाई बताई। बंदर चौंका लेकिन बोला अरे मेरा दिल तो पेड़ पर ही भूल आया। घड़ियाल वापस मुड़ा। जैसे ही किनारा आया बंदर छलांग मारकर पेड़ पर चढ़ गया और बोला दोस्ती में धोखा नहीं चलता अब कभी लौट कर मत आना।
"""

# %%
out_story2 = """
एक जंगल में एक तेज दौड़ने वाला खरगोश और एक धीरे-धीरे चलने वाला कछुआ रहते थे। खरगोश को अपनी रफ्तार पर बहुत घमंड था। वो अक्सर कछुए का मजाक उड़ाता था। इतना धीरे चलता है, तू तो कभी कहीं पहुंच ही नहीं सकता। कछुए ने शांत स्वर में कहा, एक रेस हो जाए? देखेंगे कौन जीतता है। अगले दिन सुबह रेस शुरू हुई। दोनों ने दौड़ना शुरू किया। खरगोश बहुत तेजी से आगे निकल गया। खरगोश ने देखा कि कछुआ बहुत पीछे है, तो उसने सोचा थोड़ा आराम कर लेता हूं। ये तो घंटों बाद भी नहीं पहुंचेगा। खरगोश एक पेड़ के नीचे लेट गया और गहरी नींद में सो गया। कछुआ धीरे-धीरे बिना रुके लगातार चलता रहा। उसने कभी हार नहीं मानी। जब खरगोश की नींद खुली, तब तक बहुत देर हो चुकी थी। कछुआ फिनिश लाइन पार कर चुका था। सीख: घमंड नहीं करना चाहिए। मेहनत और निरंतरता से ही जीत मिलती है।
"""

# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai
import json
from openai import OpenAI

# %%
api_key = os.getenv('GOOGLE_API_KEY')
openai_api_key = os.getenv('OPENAI_API_KEY')

genai.configure(api_key=api_key)
model = genai.GenerativeModel('gemini-2.0-flash')   
client = OpenAI(api_key=openai_api_key)
model_gpt4 = "gpt-4.1-2025-04-14"

# %%
# model.generate_content("hello")
client.chat.completions.create(
    model=model_gpt4,
    messages=[{"role": "user", "content": "hello"}]
)
# Out:
# ChatCompletion(id='chatcmpl-BN14k1BY8Suc9B6WJkbSkWmKxbgvv', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='
The competition finally began. William, a fellow who worked under the Sheriff, also participated in the competition. All the participants were wearing green outfits and started showing their skills. It was the final round for the last arrow to be shot.

Willam, the Sheriff’s man, took the aim and shot. His arrow went very close to the centre. Everyone in the audience applauded, “Yay, hurray!” “Good shot”. The Sheriff also praised William for his great performance, “Very good, William.”

Finally, it was the turn of the next contestant in the green outfit. He let go of his arrow for the aim. The arrow went straight through William’s arrow and through the bull’s eye. The audience hysterically cheered as they were surprised to see such an excellent performance.
Within that moment, the young man in a green outfit let go of two more arrows that went straight to the Sheriff and stuck on either side of his chair. The Sheriff was confused and angry at the same time. “Who is this young man?” he thought to himself.

Before the Sheriff could race his mind and recover, the man with the arrows threw off his black wig on the ground. The man was none other than Robin Hood! The Sheriff was stunned. Robin Hood then ran towards his waiting horse. After he hopped on the horse, he said to the Sheriff, “Until next time, dear Sheriff!”

Too stunned, the helpless Sheriff shouted to his guards, “Get him, you fools.” “It’s Robin Hood!” “ He is escaping.” Unfortunately for the Sheriff, it was too late; Robin Hood was long gone.
"""

# %%
prompt = f"""
you have to generate a story in english for a 10 year old child, the story should be of simpler words and should be hooky, engaging and interesting and the length of story should be strictly around 200 words
the story should be based on the following base story:
{base_story_robin}
given below is the sample input and output story:
input base story: {base_story1}

output story: {out_story1}
the output story should be in strictly in english and be of length 200 words
"""

# %%
gpt_response = client.chat.completions.create(
    model=model_gpt4,
    messages=[{"role": "user", "content": prompt}]
)
print(gpt_response.choices[0].message.content)
response = gpt_response.choices[0].message.content
# Out:
# Long ago in England, there was a place called Sherwood Forest, where a clever archer named Robin Hood lived. He had been often tricked by noblemen as a child, so he vowed to help the poor by taking from the rich. The Sheriff of Nottingham was furious at Robin and offered rewards to catch him, but Robin's friends in the forest and town always warned him of the Sheriff's plans.
#
# Tired of being outsmarted, the Sheriff hatched a plot with noblemen. "Let's hold an archery contest," he said, "with a golden arrow as the prize. Robin is the best archer and won't resist!"
#
# When Robin's friends informed him about the trap, they urged him not to go. But Robin's love for archery was too strong, and he decided to attend in disguise. At the contest, a young man in green, with a wig, dazzled the crowd by splitting the Sheriff's top archery shot with a perfect bullseye hit. The crowd cheered wildly!
#
# ...

# %%
responses_hindi =[]
responses_english =[]
for base_story in base_stories:
    prompt_hindi = f"""
    you have to generate a story in hindi for a 10 year old child, the story should be of simpler words and should be hooky, engaging and interesting and the length of story should be strictly around 200 words
    the story should be based on the following base story:
    {base_story}
    given below is the sample input and output story:
    input base story: {base_story1}

    output story: {out_story1}
    """
    prompt_english = f"""
    you have to generate a story in english for a 10 year old child, the story should be of simpler words and should be hooky, engaging and interesting and the length of story should be strictly around 200 words
    the story should be based on the following base story:
    {base_story}
    given below is the sample input and output story:
    input base story: {base_story1}

    output story: {out_story1}
    the output story should be in strictly in english and be of length 200 words
    """
    gpt_response_hindi = client.chat.completions.create(
        model=model_gpt4,
        messages=[{"role": "user", "content": prompt_hindi}]
    )
    response_hindi = gpt_response_hindi.choices[0].message.content
    print(response_hindi)
    responses_hindi.append(response_hindi)
    gpt_response_english = client.chat.completions.create(
        model=model_gpt4,
        messages=[{"role": "user", "content": prompt_english}]
    )
    response_english = gpt_response_english.choices[0].message.content
    print(response_english)
    responses_english.append(response_english)
# Out:
# एक पुराने बरगद के पेड़ पर एक कौआ और उसकी पत्नी रहते थे। दोनों ने पेड़ की डाल पर घोंसला बनाया था। उसी पेड़ के बिल में एक काला सांप भी रहता था। जब भी कौए का अंडा फूटता, सांप चुपके से आकर बच्चे खा जाता। दोनों बहुत दुखी थे, उनकी मदद कोई नहीं कर सकता था।
#
# एक दिन कौए ने अपने दोस्त सियार से सलाह मांगी। सियार बहुत समझदार था। उसने कहा, “बुद्धि से बड़े से बड़ा दुश्मन हराया जा सकता है।” सियार ने एक योजना बताई, “पास के राजा के महल जाओ और वहां से कीमती आभूषण चुराओ। फिर आस—पास के नौकर-चाकर तुम्हें देखें तो उड़कर उन्हें बरगद के बिल के पास गिरा दो। नौकर आकर सांप को मार देंगे।”
#
# कौए ने वही किया। कौआनी ने महल की रानी का हार उठा लिया और धीरे-धीरे उड़ने लगी। सैनिक हार की ओर दौड़े। कौआनी ने हार सांप के बिल के आगे गिरा दिया। सैनिक जब हार लेने आए तो सांप निकल आया। सैनिकों ने डंडों से सांप को मार दिया। अब कौए अपने बच्चों के साथ खुशी-खुशी रहने लगे।
# ...

# %%
for i in range(len(responses_hindi)):
    print(responses_hindi[i])
    print("--------------------------------")
    print(responses_english[i])
    print("--------------------------------")
# Out:
# एक पुराने बरगद के पेड़ पर एक कौआ और उसकी पत्नी रहते थे। दोनों ने पेड़ की डाल पर घोंसला बनाया था। उसी पेड़ के बिल में एक काला सांप भी रहता था। जब भी कौए का अंडा फूटता, सांप चुपके से आकर बच्चे खा जाता। दोनों बहुत दुखी थे, उनकी मदद कोई नहीं कर सकता था।
#
# एक दिन कौए ने अपने दोस्त सियार से सलाह मांगी। सियार बहुत समझदार था। उसने कहा, “बुद्धि से बड़े से बड़ा दुश्मन हराया जा सकता है।” सियार ने एक योजना बताई, “पास के राजा के महल जाओ और वहां से कीमती आभूषण चुराओ। फिर आस—पास के नौकर-चाकर तुम्हें देखें तो उड़कर उन्हें बरगद के बिल के पास गिरा दो। नौकर आकर सांप को मार देंगे।”
#
# कौए ने वही किया। कौआनी ने महल की रानी का हार उठा लिया और धीरे-धीरे उड़ने लगी। सैनिक हार की ओर दौड़े। कौआनी ने हार सांप के बिल के आगे गिरा दिया। सैनिक जब हार लेने आए तो सांप निकल आया। सैनिकों ने डंडों से सांप को मार दिया। अब कौए अपने बच्चों के साथ खुशी-खुशी रहने लगे।
# --------------------------------
# ...

# %%
# Out:
# "Once upon a time in a deep jungle, a pair of sparrows lived happily on a large tree. They had built a cozy nest that sheltered them from rain, heat, and cold. One chilly winter day, it began to rain heavily. A drenched monkey sought shelter beneath their tree, shivering from the cold. \n\nThe kind-hearted female sparrow felt sorry for him. She chirped from her nest, “Dear Monkey, you have hands and feet like humans. Why don’t you build a warm, safe home for yourself?”\n\nAlready miserable from the cold, the monkey snapped back, “You bothersome sparrow! Can't you keep quiet?”\n\nUnfazed, the female sparrow continued, explaining how her nest kept them protected and comfortable. This only fueled the monkey's anger. “She acts like a know-it-all,” he thought, growing furious with each word she spoke. The rain and chill made him so irate that he climbed up and destroyed their nest.\n\nAs the sparrows fluttered away in shock, they learned an important lesson — not everyone is open to advic
# ...

# %%
responses_english[0]
# Out:
# 'Once upon a time, in a big banyan tree, two crows—a husband and wife—built their comfy nest. But there was trouble. In the hollow of the same tree lived a wicked black cobra. Every time the mother crow laid eggs, the cobra would climb up and eat the baby crows. The poor crows were sad and scared.\n\nThey went to their clever friend, the jackal, who lived nearby. “Dear friend, how can we save our babies?” they asked. The jackal thought for a while and then shared a smart plan. “Fly to the king’s palace,” he said. “Look for something shiny and precious. Grab a necklace and make sure the palace servants see you. Fly slowly, and drop the necklace right into the cobra’s hollow. The servants will chase you and find the cobra!”\n\nRight away, the crows flew to the palace. The female crow snatched a sparkling necklace from the lakeside and flew slowly back. The servants saw her, ran after her, and reached the tree. When they saw the snake with the treasure, they fought the cobra and killed 
# ...

# %%
dialogue_history = []
for i in range(3):
    print(responses_english[i])
    print("--------------------------------")

# %%
# Out:
# dialogue history for the turn 1:
#
# --------------------------------
# dialogue for the turn 1:
# ['you: asker question for the turn 1:', 'expert: expert answer for the turn 1:']
# --------------------------------
# dialogue history for the turn 2:
# you: asker question for the turn 1:
# expert: expert answer for the turn 1:
# --------------------------------
# dialogue for the turn 2:
# ['you: asker question for the turn 1:', 'expert: expert answer for the turn 1:', 'you: asker question for the turn 2:', 'expert: expert answer for the turn 2:']
# --------------------------------
# dialogue history for the turn 3:
# you: asker question for the turn 1:
# expert: expert answer for the turn 1:
# you: asker question for the turn 2:
# expert: expert answer for the turn 2:
# --------------------------------
# dialogue for the turn 3:
# ...

# %%
dialogue = []
response_story = responses_english[0]
for i in range(3):
    dialogue_history = "\n".join(dialogue)
    prompt = f"""
    you are an helpful scene extractor from the story given below:
    {response_story}
    you have to break the following story into scenes, each scene should be only seperated from the previous one if there is a need of a different image to visualize the scene,
    you have to return the scenes in a list of strings, you just have to return the list of scenes, nothing else, do not include any other text or commentary
    the scenes should be in the same order as they are in the story, also the scenes should be in the same language as the story and the same words
    you just have to break the story into scenes and return the list of scenes, nothing else
    you should break only if there is a need of a different image to visualize the scene, otherwise do not break the story into scenes.
    These are the dialogues between you and the reviewer regarding the previous scenes extracted from the story, so look for the critics and make changes in the scenes if needed accordingly.
    dialogue history:
    {dialogue_history}
    """
    
    gpt_response = client.chat.completions.create(
        model=model_gpt4,
        messages=[{"role": "user", "content": prompt}]
    )
    response = gpt_response.choices[0].message.content
    dialogue.append(f"you: {response}")
    print(f"scene extractor for turn {i+1}: {response}")
    prompt_reviewer = f"""
    you are an helpful reviewer for scenes extraction from the story given below:
    these are the criterias that needs to be fulfilled by the scenes extracted from the story:
    1. There should be atleast 12 scenes in the story 
    2. each scene should be visually different from the previous one that is the scene should not be similar to the previous one
    3. the scenes should be having different visual elements or characters in subsequent scenes
    4. the scenes should be in the same language as the story
    5. the scenes should be in the same words as the story
    6. the scenes should be in the same order as they are in the story
    7. the scenes should be in the same style as the story
    
    this is the story:
    {response_story}
    These are the scenes extracted from the story:
    {response}
    you have to review the scenes extracted from the story and make changes in the scenes if needed accordingly.
    here are the dialogues between you and the scene extractor regarding the previous scenes extracted from the story, so look for the critics and suggest changes in the scenes if needed accordingly.
    dialogue history:
    {dialogue_history}
    """
    gpt_response_reviewer = client.chat.completions.create(
        model=model_gpt4,
        messages=[{"role": "user", "content": prompt_reviewer}]
    )
    response_reviewer = gpt_response_reviewer.choices[0].message.content
    print(f"reviewer for turn {i+1}: {response_reviewer}")
    dialogue.append(f"reviewer: {response_reviewer}")
# Out:
# scene extractor for turn 1: [
# "Once upon a time, in a big banyan tree, two crows—a husband and wife—built their comfy nest. But there was trouble. In the hollow of the same tree lived a wicked black cobra. Every time the mother crow laid eggs, the cobra would climb up and eat the baby crows. The poor crows were sad and scared.",
# "They went to their clever friend, the jackal, who lived nearby. “Dear friend, how can we save our babies?” they asked. The jackal thought for a while and then shared a smart plan.",
# "“Fly to the king’s palace,” he said. “Look for something shiny and precious. Grab a necklace and make sure the palace servants see you. Fly slowly, and drop the necklace right into the cobra’s hollow. The servants will chase you and find the cobra!”",
# "Right away, the crows flew to the palace. The female crow snatched a sparkling necklace from the lakeside and flew slowly back. The servants saw her, ran after her, and reached the tree.",
# ...

# %%
inputstr = json.loads(response)
print(len(inputstr))
print(inputstr)
# Out:
# 14
# ...

# %%
import json

# Your string
input_string = response_scenes[0]

# Parse the string into a list
story_list = json.loads(input_string)

# %%
image_prompts = []
previous_prompts=[]
for story in story_list:
    image_prompt = f"""
    you are an helpful image prompt generator from the story given below:
    {story}
    you have to generate a image prompt for the story
    the image prompt should contain all the visual elements of the story, the image prompt would be passed directly to an image generation model, so it should be in the format of an image prompt
    the image prompt should contain the character details and the scene details
    the image prompt should not include any action, it should contain only the visual elements
    the image prompts should be consistent with the previous image prompts, do not change the style of the image prompts
    the previous image prompts are:
    {previous_prompts}

    """
    gpt_response = client.chat.completions.create(
        model=model_gpt4,
        messages=[{"role": "user", "content": image_prompt}]
    )
    response = gpt_response.choices[0].message.content
    print(response)
    image_prompts.append(response)
    previous_prompts.append(response)
# Out:
# A lush, vibrant jungle with dense green foliage and shafts of sunlight filtering through the canopy. In the center stands a grand, sprawling banyan tree with thick roots and wide branches covered in leaves. Atop one sturdy branch is a neat, cozy nest, and in the nest sit two crows, a male and a female, both with glossy black feathers and intelligent eyes. The mood is peaceful and content. The background reveals the depth of the jungle, with other trees and plants visible.
# ...
